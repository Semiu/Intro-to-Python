# %% [markdown]
# # Introduction

# %% [markdown]
# Data credit:
# 1. https://www.kaggle.com/c/loan-default-prediction/data
# 2. Min, L., Amy, M., & Stanley, T. (2018). Should This Loan be Approved or Denied?: A Large Dataset with Class Assignment Guidelines, Journal of Statistics Education, 26:1, 55-66, DOI: 10.1080/10691898.2018.1434342

# %%
import pandas as pd

# %% [markdown]
# The Loan Default Prediction - Imperial College London Dataset

# %%
df = pd.read_csv("loandb/train_v2.csv", sep=",", low_memory=False)

# %%
df.head(5)
# Out:
#    id   f1  f2        f3    f4  f5     f6      f7      f8      f9  ...   f770  \
# 0   1  126  10  0.686842  1100   3  13699  7201.0  4949.0  126.75  ...      5
# 1   2  121  10  0.782776  1100   3  84645   240.0  1625.0  123.52  ...      6
# 2   3  126  10  0.500080  1100   3  83607  1800.0  1527.0  127.76  ...     13
# 3   4  134  10  0.439874  1100   3  82642  7542.0  1730.0  132.94  ...      4
# 4   5  109   9  0.502749  2900   4  79124    89.0   491.0  122.72  ...     26
#
#    f771  f772  f773    f774    f775  f776  f777  f778  loss
# 0  2.14 -1.54  1.18  0.1833  0.7873     1     0     5     0
# 1  0.54 -0.24  0.13  0.1926 -0.6787     1     0     5     0
# 2  2.89 -1.73  1.04  0.2521  0.7258     1     0     5     0
# 3  1.29 -0.89  0.66  0.2498  0.7119     1     0     5     0
# 4  6.11 -3.82  2.51  0.2282 -0.5399     0     0     5     0
#
# [5 rows x 771 columns]

# %% [markdown]
# United States Small Business Administration Loan prediction dataset

# %%
df1 = pd.read_csv("SBAnational.csv", sep=",", low_memory=False)

# %%
df1.head(5)
# Out:
#    LoanNr_ChkDgt                           Name          City State    Zip  \
# 0     1000014003                 ABC HOBBYCRAFT    EVANSVILLE    IN  47711
# 1     1000024006    LANDMARK BAR & GRILLE (THE)     NEW PARIS    IN  46526
# 2     1000034009          WHITLOCK DDS, TODD M.   BLOOMINGTON    IN  47401
# 3     1000044001  BIG BUCKS PAWN & JEWELRY, LLC  BROKEN ARROW    OK  74012
# 4     1000054004    ANASTASIA CONFECTIONS, INC.       ORLANDO    FL  32801
#
#                             Bank BankState   NAICS ApprovalDate ApprovalFY  \
# 0               FIFTH THIRD BANK        OH  451120    28-Feb-97       1997
# 1                1ST SOURCE BANK        IN  722410    28-Feb-97       1997
# 2        GRANT COUNTY STATE BANK        IN  621210    28-Feb-97       1997
# 3  1ST NATL BK & TR CO OF BROKEN        OK       0    28-Feb-97       1997
# 4        FLORIDA BUS. DEVEL CORP        FL       0    28-Feb-97       1997
#
# ...
